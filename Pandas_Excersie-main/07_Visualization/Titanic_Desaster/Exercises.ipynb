# %% [markdown]
# # Visualizing the Titanic Disaster

# %% [markdown]
# ### Introduction:
#
# This exercise is based on the titanic Disaster dataset avaiable at [Kaggle](https://www.kaggle.com/c/titanic).
# To know more about the variables check [here](https://www.kaggle.com/c/titanic/data)
#
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/thieu1995/csv-files/main/data/pandas/titanic_train.csv)

# %% [markdown]
# ### Step 3. Assign it to a variable titanic

# %%
titanic = pd.read_csv("titanic.csv")
titanic.head()

# %% [markdown]
# ### Step 4. Set PassengerId as the index

# %%
titanic = titanic.set_index("PassengerId")
titanic.head()

# %% [markdown]
# ### Step 5. Create a pie chart presenting the male/female proportion

# %%
ax = titanic["Sex"].value_counts().plot(
    kind="pie", autopct="%1.1f%%", figsize=(5, 5), ylabel=""
)
ax.set_title("Passenger Gender Proportion")
plt.show()

# %% [markdown]
# ### Step 6. Create a scatterplot with the Fare payed and the Age, differ the plot color by gender

# %%
colors = titanic["Sex"].map({"male": "steelblue", "female": "tomato"})

ax = titanic.plot.scatter(x="Age", y="Fare", c=colors, figsize=(8, 5), alpha=0.6)
ax.set_title("Fare Paid by Age and Gender")
plt.show()

# %% [markdown]
# ### Step 7. How many people survived?

# %%
titanic["Survived"].sum()

# %% [markdown]
# ### Step 8. Create a histogram with the Fare payed

# %%
ax = titanic["Fare"].plot(kind="hist", bins=30, figsize=(8, 4), color="steelblue")
ax.set_xlabel("Fare")
ax.set_title("Distribution of Fare Paid")
plt.show()

# %% [markdown]
# ### BONUS: Create your own question and answer it.

# %%
# Bonus: Survival rate by passenger class
ax = titanic.groupby("Pclass")["Survived"].mean().plot(kind="bar", color="seagreen")
ax.set_xlabel("Passenger class")
ax.set_ylabel("Survival rate")
ax.set_title("Survival Rate by Passenger Class")
plt.show()
